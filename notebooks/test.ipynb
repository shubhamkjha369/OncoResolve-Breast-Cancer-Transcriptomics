# %%
import pandas as pd

# %%
df = pd.read_csv('C:\Users\SAM\Documents\GitHub\OncoResolve-Breast-Cancer-Transcriptomics\data\external_cohort\METABRIC_clinical.csv')
# Out:
#   Cell In[3], line 1
#     df = pd.read_csv('C:\Users\SAM\Documents\GitHub\OncoResolve-Breast-Cancer-Transcriptomics\data\external_cohort\METABRIC_clinical.csv')
#                                                                                                                                          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
